# %% [markdown]
# # ResNet-50 model training using Grad attribution method

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from datasets import load_dataset
from torchsummary import summary
import numpy as np
from PIL import Image
from tqdm import tqdm
from tqdm.auto import tqdm

import numpy as np
import cv2
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import random
import time
import os
import glob

# Face recognition library
import face_recognition

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Define useful classes

# %%
# AffectNet Dataset Class

class AffectNetHqDataset(Dataset):
    def __init__(self, dataset, transform=None):
        self.dataset = dataset
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        image = item['image']
        label = item['label']

        if self.transform:
            image = self.transform(image)

        return image, label

# RAFDB Dataset Class
 
class RAFDBDataset(Dataset):
    def __init__(self, root_dir, label_dir, subset, label_file_name, transform=None):
        self.root_dir = root_dir
        self.label_dir = label_dir
        self.transform = transform
        self.subset = subset
        self.label_file_name = label_file_name
        self.labels, self.image_paths = self._load_data()

    def _load_data(self):
        labels = []
        image_paths = []
        
        labels_file_path = os.path.join(self.label_dir, self.label_file_name)
        with open(labels_file_path, 'r') as file:
            lines = file.readlines()

            for line in lines:
                parts = line.strip().split(' ')
                label = int(parts[1])
                image_path = os.path.join(self.root_dir, self.subset, parts[0])
                labels.append(label)
                image_paths.append(image_path)

        return labels, image_paths

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        label = self.labels[idx]
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert('RGB')
    
        if self.transform:
            image = self.transform(image)

        return image, label

# %% [markdown]
# ### Heatmaps Generation functions

# %%
def heatmap_generator(image):
    face_locations = face_recognition.face_locations(image)

    # Load the pre-trained facial landmark model
    face_landmarks_list = face_recognition.face_landmarks(image, face_locations)

    height, width = image.shape[:2]
    lm = np.zeros([height,width])

    # Draw facial landmarks on the image
    for face_landmarks in face_landmarks_list:
        for landmark_type, landmarks in face_landmarks.items():
            for (x, y) in landmarks:
                if x < height and y < width :
                    lm[y,x] = 1

    heatmap = cv2.GaussianBlur(lm, [59,59], 3)
    
    return heatmap

def generate_batch_heatmaps(images, heatmap_generator):
    batch_heatmaps = torch.zeros_like(images)

    for i in range(images.size(0)):
        # Convertir le tenseur PyTorch en tableau NumPy pour l'image i
        image_np = images[i].permute(1, 2, 0).cpu().detach().numpy()
        image_np = (image_np * 255).astype(np.uint8) if image_np.dtype != np.uint8 else image_np
        image_np = cv2.cvtColor(image_np, cv2.COLOR_BGR2RGB)
            
        # Générer la heatmap pour l'image actuelle
        heatmap_np = heatmap_generator(image_np)
        heatmap_tensor = torch.from_numpy(heatmap_np).float().unsqueeze(0)

        # Normaliser la heatmap et l'adapter à la taille de l'image
        heatmap_tensor = heatmap_tensor / torch.max(heatmap_tensor)
        heatmap_tensor = heatmap_tensor.repeat(3, 1, 1)

        # Stocker la heatmap dans le tenseur batch
        batch_heatmaps[i] = heatmap_tensor
    
    return batch_heatmaps

# %% [markdown]
# ### Privileged Attribution Loss

# %%
class PrivilegedAttributionLoss(nn.Module):
    def __init__(self):
        super(PrivilegedAttributionLoss, self).__init__()

    def forward(self, attribution_maps, prior_maps):
        # Add a small value to standard deviation to avoid division by zero
        epsilon = 1e-8

        # Calculate mean and standard deviation for each sample in the batch
        mean_al = torch.mean(attribution_maps, dim=[1, 2, 3], keepdim=True)  # Assuming BCHW format
        std_al = torch.std(attribution_maps, dim=[1, 2, 3], keepdim=True) + epsilon

        # Calculate the PAL loss
        # Ensure that the broadcasting in the subtraction and division is correct
        pal_loss = -torch.sum((attribution_maps - mean_al) / std_al * prior_maps, dim=[1, 2, 3])

        # Return the mean loss over the batch
        return torch.mean(pal_loss)

# %% [markdown]
# ### AffectNet Dataloader

# %%
# Load the full dataset
full_dataset = load_dataset("../datasets/AffectNet", split='train')

# Split the dataset into train and test subsets
train_size = int(0.2 * len(full_dataset))
test_size = len(full_dataset) - train_size
train_subset, test_subset = random_split(full_dataset, [train_size, test_size])

# Define transformations
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation((-10, 10)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Create the dataset and dataloader using the subsets
train_dataset = AffectNetHqDataset(Subset(full_dataset, train_subset.indices), transform=train_transform)
test_dataset = AffectNetHqDataset(Subset(full_dataset, test_subset.indices), transform=test_transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)
# Out:
# Resolving data files:   0%|          | 0/16349 [00:00<?, ?it/s]
# Found cached dataset imagefolder (C:/Users/lenov/.cache/huggingface/datasets/imagefolder/AffectNet-ac71cf06b4a145a7/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)

# %% [markdown]
# ### RAFDB Dataloader

# %%
# Transform function for train data
train_transform = transforms.Compose([
    transforms.RandomRotation(degrees=(-10, 10)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((224, 224)),  # Resize to 224x224
    transforms.ToTensor(),
])

# Transform function for test data
transform = transforms.Compose([
    transforms.ToTensor(),
])

root_dir = '../datasets/RAF-DB/Image/aligned/'
label_dir = '../datasets/RAF-DB/Image/aligned/labels'

# Create the dataset and dataloader using the subsets
RAFDB_train_dataset = RAFDBDataset(root_dir=root_dir, label_dir = label_dir, subset = 'train', label_file_name='train_label.txt', transform=transform)
RAFDB_test_dataset = RAFDBDataset(root_dir=root_dir, label_dir = label_dir, subset = 'test', label_file_name='test_label.txt', transform=transform)

RAFDB_train_loader = DataLoader(RAFDB_train_dataset, batch_size=16, shuffle=True)
RAFDB_test_loader = DataLoader(RAFDB_test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# ### Define Ploting function

# %%
def plot_element(images, batch_heatmaps, attribution_maps, gradients, i):
    
    plt.figure(figsize=(12, 8))  # Agrandir la figure pour accueillir toutes les visualisations
    # Afficher l'image original
    plt.subplot(2, 4, 1)
    image_to_show = images[i].permute(1, 2, 0).cpu().detach().numpy()
    plt.imshow(image_to_show)
    plt.title('Original Image')

    # Afficher la heatmap
    plt.subplot(2, 4, 2)
    heatmap_to_show = batch_heatmaps[i].permute(1, 2, 0).cpu().detach().numpy()
    plt.imshow(heatmap_to_show)
    plt.title('Heatmap')

    # Afficher chaque canal de la carte d'attribution
    plt.subplot(2, 4, 3)
    attribution_to_show = attribution_maps[i].detach().permute(1, 2, 0).cpu().numpy()
    attribution_norm = (attribution_to_show - attribution_to_show.min()) / (attribution_to_show.max() - attribution_to_show.min())
    attribution_mean = np.mean(attribution_norm, axis=2)
    # Appliquer une colormap 'jet' pour obtenir une carte d'attribution colorée
    cmap = plt.get_cmap('bwr')
    attribution_colored = cmap(attribution_mean)

    # Supprimer le canal alpha retourné par la colormap
    attribution_colored = attribution_colored[..., :3]
    overlayed_image = (image_to_show) * 0.2 + attribution_colored * 0.9  # Ajustez la transparence ici
    plt.imshow(overlayed_image)
    plt.title('Attribution Overlay on Original Image')

    # Afficher le gradient de sortie sur l'image originale
    plt.subplot(2, 4, 4)
    gradients_to_show = gradients[i].detach().permute(1, 2, 0).cpu().numpy()
    gradients_to_show = np.abs(gradients_to_show)
    gradients_to_show /= np.max(gradients_to_show)
                
    # Superposer le gradient sur l'image originale
    overlayed_image = (gradients_to_show * 1.5 + image_to_show * 0.2)
    plt.imshow(overlayed_image)
    plt.title('Gradient Overlay on Original Image')
    
    plt.show()

# %% [markdown]
# ### ResNet-50 model

# %%
# Load the pretrained ResNet-50 model
base_model = torchvision.models.resnet50(pretrained=True)

# Delete the last fully connected layer
base_model = nn.Sequential(*list(base_model.children())[:-1])

# Add a layer adapted to classification problem of 8 classes
num_classes = 8
classifier_layer = nn.Linear(2048, num_classes)
model = nn.Sequential(base_model, nn.Flatten(), classifier_layer)

# Plot the model summary
summary(model, (3, 224, 224))

# ResNet-50's last convolution layer
last_conv_layer = list(base_model.children())[-3][2].conv3
print("last conv layer =", last_conv_layer)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#          Flatten-174                 [-1, 2048]               0
#           Linear-175                    [-1, 8]          16,392
# ================================================================
# Total params: 23,524,424
# Trainable params: 23,524,424
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.57
# Params size (MB): 89.74
# Estimated Total Size (MB): 376.88
# ----------------------------------------------------------------
# last conv layer = Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)

# %% [markdown]
# ### Training

# %%
# Train parameters
num_epochs = 1
optimizer = optim.Adam(model.parameters(), lr=4e-5)
criterion = torch.nn.CrossEntropyLoss()
loss_values = [] 
accuracy_values = []

# %%
for epoch in range(num_epochs):

    model.train()
    running_loss = 0.0
    running_pal_loss = 0.0
    running_corrects = 0.0
    total_samples = 0.0

    for images, labels in tqdm(train_loader):
        
        # Initialiser un tenseur pour stocker toutes les heatmaps
        batch_heatmaps = generate_batch_heatmaps(images, heatmap_generator)

        # Ensure that images require gradients
        images.requires_grad_()

        # Forward pass
        outputs = model(images)
        labels = labels.long()

        model.zero_grad()
        outputs = model(images)
        outputs_max_index = torch.argmax(outputs)

        # Backward pass to get gradients
        outputs[0, output_max_index].backward()

        # Absolute gradients
        saliency_map = torch.abs(input_image.grad.data)
        
        # Get the maximum value across color channels
        saliency_map, _ = torch.max(saliency_map, dim=1)
        
        # Normalize the saliency map
        saliency_map = saliency_map / saliency_map.max()


        # Compute the classification loss
        classification_loss = criterion(outputs, labels)
        classification_loss.backward(retain_graph=True) 
        
        # Compute PAL loss
        attribution_maps = torch.autograd.grad(feature_map.sum(), images, retain_graph=True)[0]

        # Compute the PAL loss using the attribution maps and the prior maps
        pal_loss_fn = PrivilegedAttributionLoss()
        pal_loss = pal_loss_fn(attribution_maps, batch_heatmaps)

        # Compute the total loss which the the sum of the classification loss and the PAL loss
        total_loss = classification_loss + pal_loss

        # Backpropagation et optimisation
        optimizer.zero_grad()  # Clear gradients before the backward pass
        total_loss.backward()
        optimizer.step()

        # Ploting heatmaps and attribution_maps
        # if epoch == 0:
        #     for i in range(images.size(0)):
        #         plot_element(images, batch_heatmaps, attribution_maps, i)

        # Updating the running loss the PAL loss
        running_loss += classification_loss.item()
        running_pal_loss += pal_loss.item()

        # Compute Accuracy
        _, preds = torch.max(outputs, 1)
        running_corrects += torch.sum(preds == labels.data)
        total_samples += labels.size(0)

        # batch loss
        print(f'classification_loss: {classification_loss.item():.4f}, PAL Loss: {pal_loss:.4f}, Total loss: {total_loss.item():.4f}')


    # Calcul des moyennes pour l'époque
    epoch_loss = running_loss / len(train_loader)
    epoch_pal_loss = running_pal_loss / len(train_loader)
    epoch_acc = running_corrects.double() / total_samples

    # Ajouter les valeurs moyennes aux listes
    loss_values.append(epoch_loss)
    accuracy_values.append(epoch_acc)

    # Print results for each epoch
    print(f'Epoch {epoch+1}/{num_epochs}')
    print(f'Loss: {epoch_loss:.4f}, PAL Loss: {epoch_pal_loss:.4f}, Accuracy: {epoch_acc:.4f}')
# Out:
#   0%|          | 0/205 [00:00<?, ?it/s]
# classification_loss: 2.0780, PAL Loss: 0.6240, Total loss: 2.7020
# classification_loss: 2.0851, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0759, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0811, PAL Loss: 0.7137, Total loss: 2.7948
# classification_loss: 2.0833, PAL Loss: 0.6266, Total loss: 2.7098
# classification_loss: 2.0801, PAL Loss: 0.7839, Total loss: 2.8640
# classification_loss: 2.0828, PAL Loss: 0.7770, Total loss: 2.8599
# classification_loss: 2.0796, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0785, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0799, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0817, PAL Loss: 0.6643, Total loss: 2.7460
# classification_loss: 2.0853, PAL Loss: 0.6779, Total loss: 2.7632
# classification_loss: 2.0821, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0769, PAL Loss: 0.6879, Total loss: 2.7648
# classification_loss: 2.0840, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0834, PAL Loss: 0.6837, Total loss: 2.7671
# classification_loss: 2.0736, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0756, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0763, PAL Loss: 0.6714, Total loss: 2.7478
# classification_loss: 2.0729, PAL Loss: 0.7238, Total loss: 2.7967
# classification_loss: 2.0796, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0770, PAL Loss: 0.7529, Total loss: 2.8299
# classification_loss: 2.0777, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0819, PAL Loss: 0.7185, Total loss: 2.8003
# classification_loss: 2.0820, PAL Loss: 0.6597, Total loss: 2.7417
# classification_loss: 2.0774, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0826, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0744, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0747, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0746, PAL Loss: 0.6724, Total loss: 2.7470
# classification_loss: 2.0848, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0797, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0783, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0758, PAL Loss: 0.6221, Total loss: 2.6979
# classification_loss: 2.0811, PAL Loss: 0.7700, Total loss: 2.8512
# classification_loss: 2.0867, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0817, PAL Loss: 0.8125, Total loss: 2.8942
# classification_loss: 2.0804, PAL Loss: 0.6902, Total loss: 2.7706
# classification_loss: 2.0819, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0765, PAL Loss: 0.7466, Total loss: 2.8231
# classification_loss: 2.0752, PAL Loss: 0.6916, Total loss: 2.7668
# classification_loss: 2.0730, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0731, PAL Loss: 0.7047, Total loss: 2.7779
# classification_loss: 2.0765, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0819, PAL Loss: 0.7116, Total loss: 2.7934
# classification_loss: 2.0796, PAL Loss: 0.6882, Total loss: 2.7678
# classification_loss: 2.0835, PAL Loss: 0.7158, Total loss: 2.7993
# classification_loss: 2.0766, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0858, PAL Loss: 0.7757, Total loss: 2.8615
# classification_loss: 2.0852, PAL Loss: 0.7040, Total loss: 2.7892
# classification_loss: 2.0720, PAL Loss: 0.7762, Total loss: 2.8483
# classification_loss: 2.0756, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0855, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0779, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0770, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0749, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0835, PAL Loss: 0.6408, Total loss: 2.7243
# classification_loss: 2.0810, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0852, PAL Loss: 0.7269, Total loss: 2.8121
# classification_loss: 2.0800, PAL Loss: 0.8000, Total loss: 2.8801
# classification_loss: 2.0804, PAL Loss: 0.7567, Total loss: 2.8372
# classification_loss: 2.0782, PAL Loss: 0.7208, Total loss: 2.7991
# classification_loss: 2.0850, PAL Loss: 0.7005, Total loss: 2.7854
# classification_loss: 2.0814, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0820, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0794, PAL Loss: 0.7043, Total loss: 2.7837
# classification_loss: 2.0761, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0793, PAL Loss: 0.6680, Total loss: 2.7473
# classification_loss: 2.0730, PAL Loss: 0.7735, Total loss: 2.8465
# classification_loss: 2.0852, PAL Loss: 0.6538, Total loss: 2.7390
# classification_loss: 2.0809, PAL Loss: 0.7093, Total loss: 2.7902
# classification_loss: 2.0723, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0761, PAL Loss: 0.7549, Total loss: 2.8310
# classification_loss: 2.0830, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0817, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0791, PAL Loss: 0.6650, Total loss: 2.7441
# classification_loss: 2.0786, PAL Loss: 0.5886, Total loss: 2.6671
# classification_loss: 2.0842, PAL Loss: 0.7434, Total loss: 2.8276
# classification_loss: 2.0747, PAL Loss: 0.6870, Total loss: 2.7617
# classification_loss: 2.0762, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0770, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0795, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0709, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0810, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0798, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0824, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0795, PAL Loss: 0.6390, Total loss: 2.7186
# classification_loss: 2.0851, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0821, PAL Loss: 0.7060, Total loss: 2.7881
# classification_loss: 2.0786, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0783, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0815, PAL Loss: 0.7983, Total loss: 2.8798
# classification_loss: 2.0819, PAL Loss: 0.7255, Total loss: 2.8074
# classification_loss: 2.0779, PAL Loss: 0.7700, Total loss: 2.8479
# classification_loss: 2.0820, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0779, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0738, PAL Loss: 0.6749, Total loss: 2.7487
# classification_loss: 2.0790, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0769, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0775, PAL Loss: 0.7220, Total loss: 2.7995
# classification_loss: 2.0814, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0777, PAL Loss: 0.6911, Total loss: 2.7688
# classification_loss: 2.0798, PAL Loss: 0.7517, Total loss: 2.8315
# classification_loss: 2.0787, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0750, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0830, PAL Loss: 0.7096, Total loss: 2.7925
# classification_loss: 2.0811, PAL Loss: 0.6758, Total loss: 2.7569
# classification_loss: 2.0812, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0839, PAL Loss: 0.7193, Total loss: 2.8032
# classification_loss: 2.0820, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0839, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0777, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0814, PAL Loss: 0.7344, Total loss: 2.8158
# classification_loss: 2.0838, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0797, PAL Loss: 0.7948, Total loss: 2.8744
# classification_loss: 2.0775, PAL Loss: 0.5593, Total loss: 2.6369
# classification_loss: 2.0847, PAL Loss: 0.6785, Total loss: 2.7632
# classification_loss: 2.0863, PAL Loss: 0.6925, Total loss: 2.7788
# classification_loss: 2.0888, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0799, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0888, PAL Loss: 0.6682, Total loss: 2.7570
# classification_loss: 2.0880, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0794, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0800, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0746, PAL Loss: 0.6819, Total loss: 2.7565
# classification_loss: 2.0766, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0811, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0805, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0811, PAL Loss: 0.7520, Total loss: 2.8331
# classification_loss: 2.0785, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0778, PAL Loss: 0.6872, Total loss: 2.7650
# classification_loss: 2.0823, PAL Loss: 0.6886, Total loss: 2.7709
# classification_loss: 2.0787, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0780, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0818, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0755, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0763, PAL Loss: 0.6409, Total loss: 2.7172
# classification_loss: 2.0806, PAL Loss: 0.6682, Total loss: 2.7487
# classification_loss: 2.0828, PAL Loss: 0.6752, Total loss: 2.7579
# classification_loss: 2.0703, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0758, PAL Loss: 0.7641, Total loss: 2.8399
# classification_loss: 2.0855, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0761, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0808, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0827, PAL Loss: 0.5982, Total loss: 2.6810
# classification_loss: 2.0789, PAL Loss: 0.7425, Total loss: 2.8213
# classification_loss: 2.0807, PAL Loss: 0.7435, Total loss: 2.8243
# classification_loss: 2.0840, PAL Loss: 0.7507, Total loss: 2.8346
# classification_loss: 2.0750, PAL Loss: 0.7667, Total loss: 2.8417
# classification_loss: 2.0827, PAL Loss: 0.6566, Total loss: 2.7393
# classification_loss: 2.0774, PAL Loss: 0.6487, Total loss: 2.7261
# classification_loss: 2.0827, PAL Loss: 0.7366, Total loss: 2.8193
# classification_loss: 2.0771, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0773, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0792, PAL Loss: 0.7955, Total loss: 2.8748
# classification_loss: 2.0790, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0840, PAL Loss: 0.8419, Total loss: 2.9259
# classification_loss: 2.0815, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0764, PAL Loss: 0.6855, Total loss: 2.7619
# classification_loss: 2.0853, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0838, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0806, PAL Loss: 0.6337, Total loss: 2.7143
# classification_loss: 2.0841, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0791, PAL Loss: 0.7277, Total loss: 2.8068
# classification_loss: 2.0807, PAL Loss: 0.8152, Total loss: 2.8958
# classification_loss: 2.0747, PAL Loss: 0.6656, Total loss: 2.7403
# classification_loss: 2.0853, PAL Loss: 0.6914, Total loss: 2.7767
# classification_loss: 2.0813, PAL Loss: 0.7051, Total loss: 2.7864
# classification_loss: 2.0842, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0758, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0765, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0790, PAL Loss: 0.6899, Total loss: 2.7689
# classification_loss: 2.0823, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0797, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0761, PAL Loss: 0.7946, Total loss: 2.8708
# classification_loss: 2.0835, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0816, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0804, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0776, PAL Loss: 0.6250, Total loss: 2.7026
# classification_loss: 2.0761, PAL Loss: 0.6651, Total loss: 2.7411
# classification_loss: 2.0832, PAL Loss: 0.8233, Total loss: 2.9065
# classification_loss: 2.0779, PAL Loss: 0.6737, Total loss: 2.7516
# classification_loss: 2.0764, PAL Loss: 0.7610, Total loss: 2.8374
# classification_loss: 2.0770, PAL Loss: 0.6334, Total loss: 2.7104
# classification_loss: 2.0782, PAL Loss: 0.7010, Total loss: 2.7792
# classification_loss: 2.0839, PAL Loss: 0.6146, Total loss: 2.6984
# classification_loss: 2.0812, PAL Loss: 0.6389, Total loss: 2.7201
# classification_loss: 2.0820, PAL Loss: 0.6032, Total loss: 2.6852
# classification_loss: 2.0807, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0752, PAL Loss: 0.7609, Total loss: 2.8361
# classification_loss: 2.0824, PAL Loss: 0.6489, Total loss: 2.7313
# classification_loss: 2.0854, PAL Loss: 0.6618, Total loss: 2.7472
# classification_loss: 2.0814, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0791, PAL Loss: 0.5964, Total loss: 2.6755
# classification_loss: 2.0824, PAL Loss: 0.6436, Total loss: 2.7261
# classification_loss: 2.0853, PAL Loss: 0.7357, Total loss: 2.8210
# classification_loss: 2.0801, PAL Loss: 0.6445, Total loss: 2.7245
# classification_loss: 2.0788, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0744, PAL Loss: 0.6885, Total loss: 2.7629
# classification_loss: 2.0786, PAL Loss: 0.6913, Total loss: 2.7698
# classification_loss: 2.0773, PAL Loss: 0.7414, Total loss: 2.8187
# classification_loss: 2.0774, PAL Loss: 0.6336, Total loss: 2.7110
# classification_loss: 2.0820, PAL Loss: nan, Total loss: nan
# classification_loss: 2.0816, PAL Loss: 0.6592, Total loss: 2.7409
# classification_loss: 2.0718, PAL Loss: 0.6114, Total loss: 2.6832
# Epoch 1/1
# Loss: 2.0798, PAL Loss: nan, Accuracy: 0.1260
